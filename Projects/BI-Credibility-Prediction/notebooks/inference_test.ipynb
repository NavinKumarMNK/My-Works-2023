# %% [markdown]
# ### **Inference**

# %%
import json
import pandas as pd
import numpy as np
import joblib

threshold = 0.48
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 50)

# %%
kmeans_model = joblib.load('../server/models/kmeans_model.joblib')
lgbm_model = joblib.load('../server/models/lgbm.joblib')

# %%
with open('../payload.json') as f:
    data = json.load(f)

user_attributes_df = pd.DataFrame(data['user_attributes'], index=[0])
user_gpx_fixes_df = pd.DataFrame(data['user_gpx_fixes'])

# %%
user_gpx_fixes_df['cluster'] = kmeans_model.predict(user_gpx_fixes_df[['latitude', 'longitude']])
user_gpx_fixes_df.set_index('id', inplace=True)
user_gpx_fixes_df
# Out:
#              gps_fix_at     server_upload_at  longitude  latitude  accuracy  \
# id
# 1   2017-06-22 09:37:20  2017-06-22 09:43:42  36.840540 -1.294342      68.4
# 2   2017-08-14 07:50:27  2017-08-14 09:05:27  36.895270 -1.341928    1409.0
# 3   2017-06-13 10:34:29  2017-06-13 10:54:48  36.811903 -1.307220      68.4
# 4   2017-06-18 12:16:20  2017-06-18 12:16:24  36.907049 -1.309984    1581.0
# 5   2017-06-28 09:39:08  2017-06-28 09:58:12  36.839396 -1.280310    1396.0
# ..                  ...                  ...        ...       ...       ...
# 66  2017-06-25 18:24:01  2017-06-25 19:14:58  37.525418 -2.796975    4152.0
# 67  2017-04-05 08:38:57  2017-04-05 08:39:00  36.991799 -1.261228       5.4
# 68  2017-06-28 06:00:35  2017-06-28 07:08:54  36.874843 -1.341133    2007.0
# 69  2017-01-24 15:27:24  2017-01-24 15:28:32  36.903354 -1.331759      39.0
# 70  2017-03-08 12:30:59  2017-03-08 12:31:40  36.835625 -1.360590     122.4
#
#     altitude  bearing location_provider  user_id  cluster
# id
# 1        0.0      0.0             fused        1        5
# 2        0.0      0.0             fused        1        5
# 3        0.0      0.0             fused        1        5
# 4        0.0      0.0             fused        1        5
# 5        0.0      0.0             fused        1        5
# ..       ...      ...               ...      ...      ...
# 66       0.0      0.0             fused        1       20
# 67    1509.7    276.0             fused        1        5
# 68       0.0      0.0             fused        1        5
# 69       0.0      0.0             fused        1        5
# 70       0.0      0.0             fused        1        5
#
# [70 rows x 10 columns]

# %% [markdown]
# #### **Inference Feature Extractor**

# %%
def feature_extractor(df):
    def feature_extraction(df):
        df['gps_fix_at'] = pd.to_datetime(df['gps_fix_at'])
        df['server_upload_at'] = pd.to_datetime(df['server_upload_at'])
        
        
        df = df.sort_values(by=['gps_fix_at'])  
    
        if df is None or df.empty:
            return None

        # time difference calc
        df['time_in_out_diff'] = (df['server_upload_at'] - df['gps_fix_at']).dt.total_seconds()
        df['time_gps_fix_shift'] = df['gps_fix_at'].diff().dt.total_seconds() / 86400  
        df['time_gps_fix_shift'] = df['time_gps_fix_shift'].fillna(0)
        df['gps_first_server_last_diff'] = (df['server_upload_at'].iloc[-1] - df['gps_fix_at'].iloc[0]).days  
        
        # count location_provider
        df = df.replace({'location_provider': {'fused': 0, 'gps': 1, 'network': 2, 'local_database': 3}})
        location_provider_count = dict(df['location_provider'].value_counts())
        df['location_provider_count_fused'] = location_provider_count.get(0, 0)
        df['location_provider_count_gps'] = location_provider_count.get(1, 0)
        df['location_provider_count_network'] = location_provider_count.get(2, 0)
        df['location_provider_count_local_database'] = location_provider_count.get(3, 0)
        
        # altitude
        zero_count = (df['altitude'] == 0).sum()
        non_zero_count = (df['altitude'] != 0).sum()
        # [0 => city native, 1 => hilly native]
        df['altitude_native'] = 0 if zero_count > non_zero_count else 1
        df['num_travels'] = (df['bearing'] != 0).sum()
        
        # drop "gpu_fix_at", "server_upload_at" columns
        df.drop(columns=["gps_fix_at", "server_upload_at"], inplace=True)
        return df

    df = df.groupby('user_id').apply(feature_extraction).reset_index(drop=True)
    
    def aggregate_dataframe(df):
        # Handle NaN values
        df = df.fillna(0)

        # Define custom aggregation functions
        def max_(x):
            return np.max(x)
        def min_(x):
            return np.min(x)
        def std_(x):
            return np.std(x) if len(x) > 1 else np.NaN
        def mean_(x):
            return np.mean(x)
        def _(x):
            return int(np.mean(x))
        def quantile_01_(x):
            return np.quantile(x, 0.1)
        def quantile_03_(x):
            return np.quantile(x, 0.3)
        def quantile_05_(x):
            return np.quantile(x, 0.5)
        def quantile_07_(x):
            return np.quantile(x, 0.7)
        def quantile_09_(x):
            return np.quantile(x, 0.9)


        aggregations = {
            'time_in_out_diff': [max_, min_, std_, mean_, quantile_01_, quantile_03_, quantile_05_, quantile_07_, quantile_09_],
            'time_gps_fix_shift': [max_, std_, mean_,  quantile_01_, quantile_03_, quantile_05_, quantile_07_, quantile_09_],
            'longitude': [std_],
            'latitude': [std_],
            'altitude': [mean_, std_,  quantile_01_, quantile_03_, quantile_05_, quantile_07_, quantile_09_],
            'bearing': [mean_, std_,  quantile_01_, quantile_03_, quantile_05_, quantile_07_, quantile_09_],
            'accuracy': [mean_, std_,  quantile_01_, quantile_03_, quantile_05_, quantile_07_, quantile_09_],
            'gps_first_server_last_diff': [_],
            'location_provider_count_fused': [_],
            'location_provider_count_gps': [_],
            'location_provider_count_network': [_],
            'location_provider_count_local_database': [_],
            'altitude_native': [_],
            'num_travels': [_],
        }

        grouped = df.groupby('user_id')
        df_agg = grouped.agg(aggregations).reset_index()
        
        # Count occurrences of each cluster for each user_id
        for i in range(24):
            df_agg[f'cluster_{i}_count'] = df.groupby('user_id')['cluster'].apply(lambda x: (x == i).sum()).values

        # Join the multi-level column index into a single-level index
        df_agg.columns = ['_'.join(col).strip() for col in df_agg.columns.values]
        df_agg.rename(columns={'user_id_': 'user_id'}, inplace=True)
        return df_agg

    df_agg = aggregate_dataframe(df)
    df_agg.dropna()
    
    return df_agg

# %%
df = feature_extractor(user_gpx_fixes_df)

# %%
df
# Out:
#    user_id  time_in_out_diff_max_  time_in_out_diff_min_  \
# 0        1                 6735.0                    3.0
#
#    time_in_out_diff_std_  time_in_out_diff_mean_  \
# 0             1361.84606                   999.1
#
#    time_in_out_diff_quantile_01_  time_in_out_diff_quantile_03_  \
# 0                            9.7                           44.5
#
#    time_in_out_diff_quantile_05_  time_in_out_diff_quantile_07_  \
# 0                          389.0                         1230.7
#
#    time_in_out_diff_quantile_09_  time_gps_fix_shift_max_  \
# 0                         3093.0                28.945139
#
#    time_gps_fix_shift_std_  time_gps_fix_shift_mean_  \
# 0                 5.111458                  2.900228
#
#    time_gps_fix_shift_quantile_01_  time_gps_fix_shift_quantile_03_  \
# 0                          0.00736                         0.110153
#
#    time_gps_fix_shift_quantile_05_  time_gps_fix_shift_quantile_07_  \
# 0                         0.544126                         1.812738
#
#    time_gps_fix_shift_quantile_09_  longitude_std_  latitude_std_  \
# 0                        10.698556        0.539118       0.528805
#
#    altitude_mean_  altitude_std_  altitude_quantile_01_  \
# 0           75.69     323.532169                    0.0
#
#    altitude_quantile_03_  altitude_quantile_05_  ...  num_travels__  \
# 0                    0.0                    0.0  ...              3
#
#    cluster_0_count_  cluster_1_count_  cluster_2_count_  cluster_3_count_  \
# 0                 0                 0                 0                 0
#
#    cluster_4_count_  cluster_5_count_  cluster_6_count_  cluster_7_count_  \
# 0                 0                63                 2                 0
#
#    cluster_8_count_  cluster_9_count_  cluster_10_count_  cluster_11_count_  \
# 0                 0                 0                  0                  0
#
#    cluster_12_count_  cluster_13_count_  cluster_14_count_  cluster_15_count_  \
# 0                  0                  0                  0                  0
#
#    cluster_16_count_  cluster_17_count_  cluster_18_count_  cluster_19_count_  \
# 0                  1                  0                  0                  0
#
#    cluster_20_count_  cluster_21_count_  cluster_22_count_  cluster_23_count_
# 0                  3                  0                  0                  1
#
# [1 rows x 72 columns]

# %%
user_attributes_df['user_id'] = data['user_id']

# %%
data
# Out:
# {'user_id': 1,
#  'user_attributes': {'age': 42, 'cash_incoming_30days': 8988.12},
#  'user_gpx_fixes': [{'id': 1,
#    'gps_fix_at': '2017-06-22 09:37:20',
#    'server_upload_at': '2017-06-22 09:43:42',
#    'longitude': 36.8405401,
#    'latitude': -1.2943417,
#    'accuracy': 68.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 2,
#    'gps_fix_at': '2017-08-14 07:50:27',
#    'server_upload_at': '2017-08-14 09:05:27',
#    'longitude': 36.8952702,
#    'latitude': -1.3419282,
#    'accuracy': 1409.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 3,
#    'gps_fix_at': '2017-06-13 10:34:29',
#    'server_upload_at': '2017-06-13 10:54:48',
#    'longitude': 36.8119029,
#    'latitude': -1.3072201,
#    'accuracy': 68.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 4,
#    'gps_fix_at': '2017-06-18 12:16:20',
#    'server_upload_at': '2017-06-18 12:16:24',
#    'longitude': 36.9070485,
#    'latitude': -1.3099842,
#    'accuracy': 1581.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 5,
#    'gps_fix_at': '2017-06-28 09:39:08',
#    'server_upload_at': '2017-06-28 09:58:12',
#    'longitude': 36.8393959,
#    'latitude': -1.28031,
#    'accuracy': 1396.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 6,
#    'gps_fix_at': '2017-02-04 08:12:06',
#    'server_upload_at': '2017-02-04 08:12:32',
#    'longitude': 36.8786823,
#    'latitude': -1.3202525,
#    'accuracy': 19.182,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 7,
#    'gps_fix_at': '2017-06-21 17:21:50',
#    'server_upload_at': '2017-06-21 17:21:55',
#    'longitude': 36.9024832,
#    'latitude': -1.2893878,
#    'accuracy': 1700.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 8,
#    'gps_fix_at': '2017-06-20 10:08:35',
#    'server_upload_at': '2017-06-20 10:29:33',
#    'longitude': 36.885694,
#    'latitude': -1.3080455,
#    'accuracy': 1386.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 9,
#    'gps_fix_at': '2017-05-24 04:52:31',
#    'server_upload_at': '2017-05-24 05:17:26',
#    'longitude': 36.8802869,
#    'latitude': -1.289266,
#    'accuracy': 9.9,
#    'altitude': 201.4,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 10,
#    'gps_fix_at': '2017-06-17 09:44:34',
#    'server_upload_at': '2017-06-17 09:45:02',
#    'longitude': 36.8578813,
#    'latitude': -1.3150755,
#    'accuracy': 30.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 11,
#    'gps_fix_at': '2017-06-23 06:37:58',
#    'server_upload_at': '2017-06-23 06:38:03',
#    'longitude': 36.8374619,
#    'latitude': -1.2844703,
#    'accuracy': 7.0,
#    'altitude': 1730.8,
#    'bearing': 120.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 12,
#    'gps_fix_at': '2017-06-20 10:08:35',
#    'server_upload_at': '2017-06-20 10:32:59',
#    'longitude': 36.8727896,
#    'latitude': -1.3349358,
#    'accuracy': 1386.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 13,
#    'gps_fix_at': '2017-06-20 10:08:35',
#    'server_upload_at': '2017-06-20 10:25:52',
#    'longitude': 36.8906051,
#    'latitude': -1.3199154,
#    'accuracy': 1386.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 14,
#    'gps_fix_at': '2017-06-21 08:21:00',
#    'server_upload_at': '2017-06-21 08:33:02',
#    'longitude': 37.0438669,
#    'latitude': -1.047769,
#    'accuracy': 2183.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 15,
#    'gps_fix_at': '2017-06-25 17:07:39',
#    'server_upload_at': '2017-06-25 17:42:20',
#    'longitude': 37.5229275,
#    'latitude': -2.9327878,
#    'accuracy': 3801.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 20},
#   {'id': 16,
#    'gps_fix_at': '2017-06-28 05:48:58',
#    'server_upload_at': '2017-06-28 05:51:33',
#    'longitude': 36.8851367,
#    'latitude': -1.3268858,
#    'accuracy': 2178.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 17,
#    'gps_fix_at': '2017-06-17 03:13:29',
#    'server_upload_at': '2017-06-17 03:15:04',
#    'longitude': 36.9215864,
#    'latitude': -1.2978782,
#    'accuracy': 1327.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 18,
#    'gps_fix_at': '2017-06-23 04:28:05',
#    'server_upload_at': '2017-06-23 04:47:40',
#    'longitude': 36.8725918,
#    'latitude': -1.321248,
#    'accuracy': 2007.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 19,
#    'gps_fix_at': '2017-01-24 04:54:59',
#    'server_upload_at': '2017-01-24 04:55:06',
#    'longitude': 36.9184219,
#    'latitude': -1.2902526,
#    'accuracy': 34.5,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 20,
#    'gps_fix_at': '2017-03-14 08:55:09',
#    'server_upload_at': '2017-03-14 08:55:27',
#    'longitude': 35.0030903,
#    'latitude': 0.9974602,
#    'accuracy': 20.887,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 16},
#   {'id': 21,
#    'gps_fix_at': '2017-05-28 15:10:03',
#    'server_upload_at': '2017-05-28 15:24:09',
#    'longitude': 36.8039008,
#    'latitude': -1.3047643,
#    'accuracy': 20.225,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 22,
#    'gps_fix_at': '2017-06-18 15:55:36',
#    'server_upload_at': '2017-06-18 16:02:12',
#    'longitude': 36.9048221,
#    'latitude': -1.3151352,
#    'accuracy': 1403.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 23,
#    'gps_fix_at': '2017-04-05 12:59:59',
#    'server_upload_at': '2017-04-05 13:00:58',
#    'longitude': 36.832885,
#    'latitude': -1.2906123,
#    'accuracy': 72.574,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 24,
#    'gps_fix_at': '2017-04-17 13:08:19',
#    'server_upload_at': '2017-04-17 13:12:26',
#    'longitude': 36.9096241,
#    'latitude': -1.300384,
#    'accuracy': 1700.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 25,
#    'gps_fix_at': '2017-07-01 08:56:43',
#    'server_upload_at': '2017-07-01 09:20:52',
#    'longitude': 36.8648109,
#    'latitude': -1.3321068,
#    'accuracy': 1714.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 26,
#    'gps_fix_at': '2017-06-22 10:57:09',
#    'server_upload_at': '2017-06-22 11:57:04',
#    'longitude': 36.8273951,
#    'latitude': -1.2776204,
#    'accuracy': 20.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 27,
#    'gps_fix_at': '2017-05-04 10:17:11',
#    'server_upload_at': '2017-05-04 10:17:44',
#    'longitude': 36.827091,
#    'latitude': -1.2700201,
#    'accuracy': 19.902,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 28,
#    'gps_fix_at': '2017-08-15 05:18:00',
#    'server_upload_at': '2017-08-15 05:34:09',
#    'longitude': 36.8821622,
#    'latitude': -1.3711277,
#    'accuracy': 1371.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 29,
#    'gps_fix_at': '2017-06-20 10:39:09',
#    'server_upload_at': '2017-06-20 10:52:10',
#    'longitude': 36.9029065,
#    'latitude': -1.32786,
#    'accuracy': 1564.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 30,
#    'gps_fix_at': '2017-06-18 12:52:00',
#    'server_upload_at': '2017-06-18 13:22:59',
#    'longitude': 36.8941067,
#    'latitude': -1.2833341,
#    'accuracy': 1527.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 31,
#    'gps_fix_at': '2017-06-23 06:51:22',
#    'server_upload_at': '2017-06-23 06:51:45',
#    'longitude': 36.8397065,
#    'latitude': -1.3268054,
#    'accuracy': 2324.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 32,
#    'gps_fix_at': '2017-08-14 16:39:00',
#    'server_upload_at': '2017-08-14 16:49:34',
#    'longitude': 36.935553,
#    'latitude': -1.2944883,
#    'accuracy': 1759.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 33,
#    'gps_fix_at': '2017-03-03 11:06:29',
#    'server_upload_at': '2017-03-03 11:07:07',
#    'longitude': 36.7819762,
#    'latitude': -1.2731753,
#    'accuracy': 25.626,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 34,
#    'gps_fix_at': '2017-06-26 11:31:44',
#    'server_upload_at': '2017-06-26 11:38:52',
#    'longitude': 37.5403607,
#    'latitude': -2.8116126,
#    'accuracy': 4152.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 20},
#   {'id': 35,
#    'gps_fix_at': '2017-07-05 04:56:18',
#    'server_upload_at': '2017-07-05 05:21:21',
#    'longitude': 36.9114528,
#    'latitude': -1.3132867,
#    'accuracy': 1190.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 36,
#    'gps_fix_at': '2017-07-01 10:20:00',
#    'server_upload_at': '2017-07-01 11:20:49',
#    'longitude': 36.8746882,
#    'latitude': -1.3307935,
#    'accuracy': 1379.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 37,
#    'gps_fix_at': '2017-03-16 11:50:47',
#    'server_upload_at': '2017-03-16 11:51:38',
#    'longitude': 34.8426223,
#    'latitude': 0.0862141,
#    'accuracy': 3587.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 6},
#   {'id': 38,
#    'gps_fix_at': '2017-06-25 05:37:00',
#    'server_upload_at': '2017-06-25 05:39:09',
#    'longitude': 36.911372,
#    'latitude': -1.296947,
#    'accuracy': 1576.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 39,
#    'gps_fix_at': '2017-06-22 13:42:26',
#    'server_upload_at': '2017-06-22 14:39:23',
#    'longitude': 36.8975859,
#    'latitude': -1.2964753,
#    'accuracy': 1700.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 40,
#    'gps_fix_at': '2017-06-19 09:22:53',
#    'server_upload_at': '2017-06-19 09:57:05',
#    'longitude': 36.8006398,
#    'latitude': -1.2703072,
#    'accuracy': 1319.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 41,
#    'gps_fix_at': '2017-06-13 11:44:43',
#    'server_upload_at': '2017-06-13 11:47:24',
#    'longitude': 36.8396357,
#    'latitude': -1.271307,
#    'accuracy': 22.5,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 42,
#    'gps_fix_at': '2017-07-16 09:09:27',
#    'server_upload_at': '2017-07-16 09:59:35',
#    'longitude': 36.9243249,
#    'latitude': -1.3257184,
#    'accuracy': 96.0,
#    'altitude': 1515.4,
#    'bearing': 179.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 43,
#    'gps_fix_at': '2017-06-19 04:40:41',
#    'server_upload_at': '2017-06-19 06:32:56',
#    'longitude': 36.8980049,
#    'latitude': -1.3214476,
#    'accuracy': 1327.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 44,
#    'gps_fix_at': '2017-01-24 05:10:45',
#    'server_upload_at': '2017-01-24 05:10:56',
#    'longitude': 36.9162066,
#    'latitude': -1.3252386,
#    'accuracy': 36.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 45,
#    'gps_fix_at': '2017-06-22 12:37:29',
#    'server_upload_at': '2017-06-22 12:48:18',
#    'longitude': 36.879292,
#    'latitude': -1.3293361,
#    'accuracy': 1974.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 46,
#    'gps_fix_at': '2017-06-15 06:54:00',
#    'server_upload_at': '2017-06-15 08:03:49',
#    'longitude': 36.9145836,
#    'latitude': -1.3154634,
#    'accuracy': 1424.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 47,
#    'gps_fix_at': '2017-06-23 05:47:38',
#    'server_upload_at': '2017-06-23 05:53:29',
#    'longitude': 36.8263237,
#    'latitude': -1.2876123,
#    'accuracy': 68.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 48,
#    'gps_fix_at': '2017-06-20 03:35:11',
#    'server_upload_at': '2017-06-20 04:02:33',
#    'longitude': 36.8981508,
#    'latitude': -1.3109904,
#    'accuracy': 1580.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 49,
#    'gps_fix_at': '2017-05-11 17:58:23',
#    'server_upload_at': '2017-05-11 17:58:26',
#    'longitude': 36.9032593,
#    'latitude': -1.2998062,
#    'accuracy': 1334.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 50,
#    'gps_fix_at': '2017-01-24 06:46:18',
#    'server_upload_at': '2017-01-24 06:47:04',
#    'longitude': 36.9062843,
#    'latitude': -1.3193675,
#    'accuracy': 37.5,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 51,
#    'gps_fix_at': '2017-06-24 16:15:00',
#    'server_upload_at': '2017-06-24 16:45:08',
#    'longitude': 36.9088534,
#    'latitude': -1.2849451,
#    'accuracy': 1693.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 52,
#    'gps_fix_at': '2017-02-06 09:42:23',
#    'server_upload_at': '2017-02-06 09:44:10',
#    'longitude': 36.7919605,
#    'latitude': -1.2619843,
#    'accuracy': 40.5,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 53,
#    'gps_fix_at': '2017-06-20 10:39:09',
#    'server_upload_at': '2017-06-20 10:47:44',
#    'longitude': 36.9106903,
#    'latitude': -1.3411914,
#    'accuracy': 1564.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 54,
#    'gps_fix_at': '2017-05-13 11:55:37',
#    'server_upload_at': '2017-05-13 12:00:18',
#    'longitude': 36.893156,
#    'latitude': -1.3357839,
#    'accuracy': 1216.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 55,
#    'gps_fix_at': '2017-03-26 10:53:02',
#    'server_upload_at': '2017-03-26 10:53:37',
#    'longitude': 36.896831,
#    'latitude': -1.33533,
#    'accuracy': 128.9,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 56,
#    'gps_fix_at': '2017-06-22 09:37:20',
#    'server_upload_at': '2017-06-22 10:02:31',
#    'longitude': 36.8327349,
#    'latitude': -1.2573608,
#    'accuracy': 68.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 57,
#    'gps_fix_at': '2017-05-04 15:13:01',
#    'server_upload_at': '2017-05-04 15:18:51',
#    'longitude': 36.9112094,
#    'latitude': -1.3180901,
#    'accuracy': 56.1,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 58,
#    'gps_fix_at': '2017-04-10 07:30:03',
#    'server_upload_at': '2017-04-10 07:30:06',
#    'longitude': 36.838068,
#    'latitude': -1.2594496,
#    'accuracy': 26.648,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 59,
#    'gps_fix_at': '2017-03-02 15:52:13',
#    'server_upload_at': '2017-03-02 15:52:40',
#    'longitude': 36.9179937,
#    'latitude': -1.3114916,
#    'accuracy': 313.072,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 60,
#    'gps_fix_at': '2017-03-14 19:01:03',
#    'server_upload_at': '2017-03-14 19:01:35',
#    'longitude': 34.0930003,
#    'latitude': 0.470514,
#    'accuracy': 50.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 23},
#   {'id': 61,
#    'gps_fix_at': '2017-02-18 15:02:12',
#    'server_upload_at': '2017-02-18 15:12:50',
#    'longitude': 36.8805829,
#    'latitude': -1.3161596,
#    'accuracy': 16.1,
#    'altitude': 341.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 62,
#    'gps_fix_at': '2017-03-01 09:53:26',
#    'server_upload_at': '2017-03-01 09:54:01',
#    'longitude': 36.8195067,
#    'latitude': -1.2896817,
#    'accuracy': 98.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 63,
#    'gps_fix_at': '2017-03-28 08:18:22',
#    'server_upload_at': '2017-03-28 08:18:32',
#    'longitude': 36.8775196,
#    'latitude': -1.2693856,
#    'accuracy': 1440.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 64,
#    'gps_fix_at': '2017-03-16 11:49:21',
#    'server_upload_at': '2017-03-16 11:49:32',
#    'longitude': 34.8373692,
#    'latitude': 0.1152443,
#    'accuracy': 4434.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 6},
#   {'id': 65,
#    'gps_fix_at': '2017-06-20 10:39:09',
#    'server_upload_at': '2017-06-20 11:04:42',
#    'longitude': 36.8970224,
#    'latitude': -1.321691,
#    'accuracy': 1564.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 66,
#    'gps_fix_at': '2017-06-25 18:24:01',
#    'server_upload_at': '2017-06-25 19:14:58',
#    'longitude': 37.5254177,
#    'latitude': -2.7969746,
#    'accuracy': 4152.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 20},
#   {'id': 67,
#    'gps_fix_at': '2017-04-05 08:38:57',
#    'server_upload_at': '2017-04-05 08:39:00',
#    'longitude': 36.9917987,
#    'latitude': -1.2612279,
#    'accuracy': 5.4,
#    'altitude': 1509.7,
#    'bearing': 276.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 68,
#    'gps_fix_at': '2017-06-28 06:00:35',
#    'server_upload_at': '2017-06-28 07:08:54',
#    'longitude': 36.8748426,
#    'latitude': -1.3411335,
#    'accuracy': 2007.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 69,
#    'gps_fix_at': '2017-01-24 15:27:24',
#    'server_upload_at': '2017-01-24 15:28:32',
#    'longitude': 36.9033537,
#    'latitude': -1.3317585,
#    'accuracy': 39.0,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5},
#   {'id': 70,
#    'gps_fix_at': '2017-03-08 12:30:59',
#    'server_upload_at': '2017-03-08 12:31:40',
#    'longitude': 36.8356249,
#    'latitude': -1.3605903,
#    'accuracy': 122.4,
#    'altitude': 0.0,
#    'bearing': 0.0,
#    'location_provider': 'fused',
#    'user_id': 1,
#    'cluster': 5}]}

# %%
df = df.merge(user_attributes_df, on='user_id')
df
# Out:
#    user_id  time_in_out_diff_max_  time_in_out_diff_min_  \
# 0        1                 6735.0                    3.0
#
#    time_in_out_diff_std_  time_in_out_diff_mean_  \
# 0             1361.84606                   999.1
#
#    time_in_out_diff_quantile_01_  time_in_out_diff_quantile_03_  \
# 0                            9.7                           44.5
#
#    time_in_out_diff_quantile_05_  time_in_out_diff_quantile_07_  \
# 0                          389.0                         1230.7
#
#    time_in_out_diff_quantile_09_  time_gps_fix_shift_max_  \
# 0                         3093.0                28.945139
#
#    time_gps_fix_shift_std_  time_gps_fix_shift_mean_  \
# 0                 5.111458                  2.900228
#
#    time_gps_fix_shift_quantile_01_  time_gps_fix_shift_quantile_03_  \
# 0                          0.00736                         0.110153
#
#    time_gps_fix_shift_quantile_05_  time_gps_fix_shift_quantile_07_  \
# 0                         0.544126                         1.812738
#
#    time_gps_fix_shift_quantile_09_  longitude_std_  latitude_std_  \
# 0                        10.698556        0.539118       0.528805
#
#    altitude_mean_  altitude_std_  altitude_quantile_01_  \
# 0           75.69     323.532169                    0.0
#
#    altitude_quantile_03_  altitude_quantile_05_  ...  cluster_1_count_  \
# 0                    0.0                    0.0  ...                 0
#
#    cluster_2_count_  cluster_3_count_  cluster_4_count_  cluster_5_count_  \
# 0                 0                 0                 0                63
#
#    cluster_6_count_  cluster_7_count_  cluster_8_count_  cluster_9_count_  \
# 0                 2                 0                 0                 0
#
#    cluster_10_count_  cluster_11_count_  cluster_12_count_  cluster_13_count_  \
# 0                  0                  0                  0                  0
#
#    cluster_14_count_  cluster_15_count_  cluster_16_count_  cluster_17_count_  \
# 0                  0                  0                  1                  0
#
#    cluster_18_count_  cluster_19_count_  cluster_20_count_  cluster_21_count_  \
# 0                  0                  0                  3                  0
#
#    cluster_22_count_  cluster_23_count_  age  cash_incoming_30days
# 0                  0                  1   42               8988.12
#
# [1 rows x 74 columns]

# %%
int(lgbm_model.predict_proba(df.drop(columns=['user_id']))[0][1] > threshold)
# Out:
# 1

# %%
lgbm_model.predict_proba(df.drop(columns=['user_id']))
# Out:
# array([[0.4942382, 0.5057618]])
